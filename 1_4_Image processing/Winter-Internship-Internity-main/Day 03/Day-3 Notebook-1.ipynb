# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\TANVI\Desktop\New folder\Online Retail.xlsx")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_excel(r"C:\Users\TANVI\Desktop\New folder\Online Retail.xlsx")
#       2 df
#
# File ~\.conda\envs\Work_Py_4\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
#1-a(i)
df1=df[['InvoiceNo','StockCode','Description','Quantity']].copy()
df1=df1.loc[df.InvoiceNo==536544]
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #1-a(i)
# ----> 2 df1=df[['InvoiceNo','StockCode','Description','Quantity']].copy()
#       3 df1=df1.loc[df.InvoiceNo==536544]
#       4 df1
#
# NameError: name 'df' is not defined

# %%
#1-b(i)
df2=df['UnitPrice']
print("Min =",df2.min(axis=0),"\nMax =",df2.max(axis=0),"\nMedian =",df2.median(),"\nMean =",df2.mean(),"\nStandard Deviation =",df2.std(),"\nVariance =",df2.var(),"\nSum =",df2.sum(),"\nCount =",df2.count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #1-b(i)
# ----> 2 df2=df['UnitPrice']
#       3 print("Min =",df2.min(axis=0),"\nMax =",df2.max(axis=0),"\nMedian =",df2.median(),"\nMean =",df2.mean(),"\nStandard Deviation =",df2.std(),"\nVariance =",df2.var(),"\nSum =",df2.sum(),"\nCount =",df2.count())
#
# NameError: name 'df' is not defined

# %%
#1-c(i)
df3=pd.read_excel(r"C:\Users\TANVI\Desktop\New folder\Online Retail.xlsx",skiprows=[i for i in range(1,101)])
df3
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536378    84519A      TOMATO CHARLIE+LOLA COASTER SET         6
# 1         536378    85183B  CHARLIE & LOLA WASTEPAPER BIN FLORA        48
# 2         536378    85071B   RED CHARLIE+LOLA PERSONAL DOORSIGN        96
# 3         536378     21931               JUMBO STORAGE BAG SUKI        10
# 4         536378     21929       JUMBO BAG PINK VINTAGE PAISLEY        10
# 5         536380     22961               JAM MAKING SET PRINTED        24
# 6         536381     22139     RETROSPOT TEA SET CERAMIC 11 PC         23
# 7         536381     84854                  GIRLY PINK TOOL SET         5
# 8         536381     22411    JUMBO SHOPPER VINTAGE RED PAISLEY        10
# 9         536381     82567            AIRLINE LOUNGE,METAL SIGN         2
# 10        536381     21672   WHITE SPOT RED CERAMIC DRAWER KNOB         6
# 11        536381     22774    RED DRAWER KNOB ACRYLIC EDWARDIAN        24
# ...

# %%
df3['InvoiceNo'] = df['InvoiceNo'].astype(int)
df3.sort_values(by=['InvoiceNo'], inplace=True)

# %%
#1-c(ii)
D=df3['Description'].str.startswith('D', na=False)
df3[D]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 40        536381     21523   DOORMAT FANCY FONT HOME SWEET HOME        10
# 41       C536379         D                             Discount        -1
# 85        536388     21523   DOORMAT FANCY FONT HOME SWEET HOME         2
# 119       536390     20668      DISCO BALL CHRISTMAS DECORATION       288
# 128       536390     22654                   DELUXE SEWING KIT         40
# 159       536394     22349         DOG BOWL CHASING BALL DESIGN        12
# 203       536398     48185                   DOORMAT FAIRY CAKE         2
# 235       536401     21464  DISCO BALL ROTATOR BATTERY OPERATED         1
# 240       536401     48129                      DOORMAT TOPIARY         1
# 354       536408     20685                DOORMAT RED RETROSPOT         2
# 355       536408     48194                       DOORMAT HEARTS         2
# 399       536409     21955    DOORMAT UNION JACK GUNS AND ROSES         1
# ...

# %%
#2-a(i)
df4=[['Tanvi','30-04-2002',100],['Akshara','05-07-2001',85],['Ridhima','15-04-2000',90],['Maya','28-09-2000',78],['Ayesha','01-01-2001',55]]
df4=pd.DataFrame(df4,columns=['Name','DOB','Marks'])
df4
# Out:
#       Name         DOB  Marks
# 0    Tanvi  30-04-2002    100
# 1  Akshara  05-07-2001     85
# 2  Ridhima  15-04-2000     90
# 3     Maya  28-09-2000     78
# 4   Ayesha  01-01-2001     55

# %%
#2-a(ii)
df5={'Name':['Tanvi','Akshara','Ridhima','Maya','Ayesha'],'DOB':['30-04-2002','05-07-2001','15-04-2000','28-09-2000','01-01-2001'],'Marks':[100,85,90,78,55]}
df5=pd.DataFrame(df5)
df5
# Out:
#       Name         DOB  Marks
# 0    Tanvi  30-04-2002    100
# 1  Akshara  05-07-2001     85
# 2  Ridhima  15-04-2000     90
# 3     Maya  28-09-2000     78
# 4   Ayesha  01-01-2001     55

# %%
#2-a(iii)
df6=[{'Name':'Tanvi','DOB':'30-04-2002','Marks':100},{'Name':'Akshara','DOB':'05-07-2001','Marks':85},{'Name':'Ridhima','DOB':'15-04-2000','Marks':90},{'Name':'Maya','DOB':'28-09-2000','Marks':78},{'Name':'Ayesha','DOB':'01-01-2001','Marks':55}]
df6=pd.DataFrame(df6)
df6
# Out:
#           DOB  Marks     Name
# 0  30-04-2002    100    Tanvi
# 1  05-07-2001     85  Akshara
# 2  15-04-2000     90  Ridhima
# 3  28-09-2000     78     Maya
# 4  01-01-2001     55   Ayesha

# %%
#2-a(iv)
Name=pd.Series(['Tanvi','Akshara','Ridhima','Maya','Ayesha'])
DOB=pd.Series(['30-04-2002','05-07-2001','15-04-2000','28-09-2000','01-01-2001'])
Marks=pd.Series([100,85,90,78,55])
data={'Name':Name,'DOB':DOB,'Marks':Marks}
df7=pd.DataFrame(*[data])
df7
# Out:
#       Name         DOB  Marks
# 0    Tanvi  30-04-2002    100
# 1  Akshara  05-07-2001     85
# 2  Ridhima  15-04-2000     90
# 3     Maya  28-09-2000     78
# 4   Ayesha  01-01-2001     55

# %%
#2-b
df8=pd.DataFrame(columns=['Student Name','DOB','English Marks'])
df8=df8.append({'Student Name':'Tanvi','DOB':'30-04-2002','English Marks':100},ignore_index = True)
df8=df8.append({'Student Name':'Akshara','DOB':'05-07-2001','English Marks':85},ignore_index = True)
df8=df8.append({'Student Name':'Ridhima','DOB':'15-04-2000','English Marks':90},ignore_index = True)
df8=df8.append({'Student Name':'Maya','DOB':'28-09-2000','English Marks':78},ignore_index = True)
df8=df8.append({'Student Name':'Ayesha','DOB':'01-01-2001','English Marks':55},ignore_index = True)
df8
# Out:
#   Student Name         DOB English Marks
# 0        Tanvi  30-04-2002           100
# 1      Akshara  05-07-2001            85
# 2      Ridhima  15-04-2000            90
# 3         Maya  28-09-2000            78
# 4       Ayesha  01-01-2001            55

# %%
#3-a
import random
ser1,ser2=random.sample(range(-100,100),100),random.sample(range(-100,100),100)
ser1,ser2=pd.Series(ser1),pd.Series(ser2),

# %%
#3-b
add=ser1.add(ser2,fill_value=0)
sub=ser1.sub(ser2,fill_value=0)
mul=ser1.mul(ser2,fill_value=0)
div=ser1.div(ser2,fill_value=0)

# %%
#3-c
df9=pd.DataFrame({'Number 1':ser1,'Number 2':ser2,'add':add,'sub':sub,'mult':mul,'div':div})
df9
# Out:
#     Number 1  Number 2  add  sub  mult        div
# 0         13       -36  -23   49  -468  -0.361111
# 1        -67       -55 -122  -12  3685   1.218182
# 2        -69       -81 -150   12  5589   0.851852
# 3         34       -98  -64  132 -3332  -0.346939
# 4         72       -65    7  137 -4680  -1.107692
# 5        -59        43  -16 -102 -2537  -1.372093
# 6        -62         9  -53  -71  -558  -6.888889
# 7         15         2   17   13    30   7.500000
# 8         28        28   56    0   784   1.000000
# 9         46       -83  -37  129 -3818  -0.554217
# 10        45       -46   -1   91 -2070  -0.978261
# 11         7       -16   -9   23  -112  -0.437500
# 12       -90        74  -16 -164 -6660  -1.216216
# 13        -7        78   71  -85  -546  -0.089744
# 14        74        21   95   53  1554   3.523810
# 15        80       -73    7  153 -5840  -1.095890
# 16        67       -62    5  129 -4154  -1.080645
# 17        31         1   32   30    31  31.000000
# ...
