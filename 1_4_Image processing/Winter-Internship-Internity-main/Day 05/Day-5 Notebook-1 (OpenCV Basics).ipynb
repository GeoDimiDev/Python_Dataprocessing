# %%
import numpy as np
import cv2 # OpenCV-Python
# %matplotlib inline
import matplotlib.pyplot as plt

print("OpenCV-Python Version %s" % cv2.__version__)
# Out:
# OpenCV-Python Version 4.8.1

# %%
img = cv2.imread('images/messi.jpg', cv2.IMREAD_COLOR)

# If the image path is wrong, the resulting img will be none
if img is None:
    print 'Open Error'
else:
    print 'Image Loaded'
# Out:
#   Cell In[2], line 5
#     print 'Open Error'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# Check the resulting img
print type(img)
print img.shape
print img.dtype
print img[:2, :2, :]  # Right-upper-most few pixels of the image
# Out:
#   Cell In[3], line 2
#     print type(img)
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# display an image using matplotlib
# plt.imshow(img) # => The color of this line is wrong
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # display an image using matplotlib
#       2 # plt.imshow(img) # => The color of this line is wrong
# ----> 3 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#
# NameError: name 'img' is not defined

# %%
# Access a pixel value(BGR order)
img[50, 235]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Access a pixel value(BGR order)
# ----> 2 img[50, 235]
#
# NameError: name 'img' is not defined

# %%
# Change pixel values
for i in range(5):
    for j in range(5):
        img[50+i, 235+j] = (0, 255, 0)
# => Green dot above messi's head

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 for i in range(5):
#       3     for j in range(5):
# ----> 4         img[50+i, 235+j] = (0, 255, 0)
#       5 # => Green dot above messi's head
#       7 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#
# NameError: name 'img' is not defined

# %%
# ROI is obtained using Numpy indexing 
ball = img[280:340, 330:390]
img[273:333, 100:160] = ball

# img[50:55, 235:240] = (0, 255, 0)  # The for-loop in the code block above is equavalent to this line. 

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
